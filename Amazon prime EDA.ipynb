# %% [markdown]
# **NAME: KARINA KATRE**

# %% [markdown]
# # **Project Name**    : Exploratory Data Analysis of Amazon Prime Videos Content library

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The goal of this project is to perform exploratory data analysis (EDA) on the Amazon Prime Video dataset, focusing on understanding the content catalog of TV shows and movies available on the platform. The analysis uncovers trends, insights, and patterns related to content type, genre distribution, ratings, release years, and regional availability. A
#
# Key steps:
#
# 1.Data Collection and Cleaning: The project used two datasets containing information about titles and credits for movies and TV shows on Amazon Prime Video. The data was cleaned by handling missing values, removing duplicates, and ensuring data consistency
#
# 2.Data Visualization: Various visualization techniques were used, including box plots, histograms, bar plote, scatter plots, line plots, pie charts, and violin plots. These visualizations helped uncover patterns and relationships within the data.
#
# 3.Insights: The analysis revealed several key insights:
#
# Amazon Prime Video has more movies than TV shows. Drama and comedy are the most common genres.
#
# Movie runtimes have slightly decreased over the years, while TV shows have more seasons.
#
# Older titles tend to have higher ratings than newer releases.
#
# The United States is the primary content producer, followed by India and the United Kingdom.
#
# This EDA provides valuable information for understanding the landscape of Amazon Prime Vided's content. Content creators, platform strategists, and viewers can benefit from this analysis for making informed decisions. Future research could focus on specific genres,
# Older titles tend to have higher ratings than newer releases.
#
# The United States is the primary content producer, followed by India and the United Kingdom.
#
# This EDA provides valuable information for understanding the landscape of Amazon Prime Video's content. Content creators, platform strategists, and viewers can benefit from this analysis for making informed decisions. Future research could focus on specific genres, regions, or content types for deeper insights.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/karina1508-aug/Amazon_prime_EDA

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# This dataset was created to analyze all shows available on Amazon Prime Video, allowing us to extract valuable insights such
#
# Content Diversity: Understanding the dominant genres and categories on Amazon Prime is crucial for strategic content planing. The problem statement highlights the need to analyze content diversity.
#
# Trends Over Time: The entertainment landscape evolves constantly. The problem statement emphasizes the importance of analyzing how Amazon Prime's content library has changed to adapt to viewer preferences and market trends.
#
# IMDb Ratings & Popularity: IMDb ratings and popularity scores offer valuable insights into viewer engagement and satisfaction. The problem statement highlights the need to analyze these metrics to identify high-performing content and potential arean for improvement

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To analyze Amazon Prime Video’s content library in order to optimize content planning, enhance viewer engagement, and improve platform performance by understanding genre diversity, content trends, and IMDb-based audience preferences.

# %% [markdown]
# ### Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
data1= pd.read_csv(r"C:\Users\katre\OneDrive\Documents\Amazon prime EDA\titles.csv")
data2= pd.read_csv(r"C:\Users\katre\OneDrive\Documents\Amazon prime EDA\credits.csv")

# %% [markdown]
# ### Dataset First View

# %%
data1.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
data=pd.merge(data1,data2, on= 'id')

# %%
data.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3               NaN       78
# 4               NaN       78
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Rows:", data.shape[0])
print("Columns:", data.shape[1])
# Out:
# Rows: 124347
# Columns: 19

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124347 entries, 0 to 124346
# Data columns (total 19 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    124347 non-null  object
#  1   title                 124347 non-null  object
#  2   type                  124347 non-null  object
#  3   description           124256 non-null  object
#  4   release_year          124347 non-null  int64
#  5   age_certification     56707 non-null   object
#  6   runtime               124347 non-null  int64
#  7   genres                124347 non-null  object
#  8   production_countries  124347 non-null  object
#  9   seasons               8153 non-null    float64
#  10  imdb_id               119044 non-null  object
#  11  imdb_score            118296 non-null  float64
#  12  imdb_votes            118272 non-null  float64
#  13  tmdb_popularity       124332 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print("The Duplicate value in dataset are: ",data.duplicated().sum())
# Out:
# The Duplicate value in dataset are:  168

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print("The missing or null value in the dataset are :", data.isnull().sum())
# Out:
# The missing or null value in the dataset are : id                           0
# title                        0
# type                         0
# description                 91
# release_year                 0
# age_certification        67640
# runtime                      0
# genres                       0
# production_countries         0
# seasons                 116194
# imdb_id                   5303
# imdb_score                6051
# imdb_votes                6075
# tmdb_popularity             15
# tmdb_score               10265
# person_id                    0
# name                         0
# character                16307
# role                         0
# dtype: int64

# %%
# Visualizing the missing values

# Convert missing values (True/False) into 1/0 matrix
missing_matrix = data.isnull().astype(int).values

plt.figure(figsize=(12, 6))
plt.imshow(missing_matrix, aspect='auto')

plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Rows")

plt.xticks(ticks=np.arange(len(data.columns)), labels=data.columns, rotation=90)
plt.yticks([])  # Hide row numbers for clarity

plt.show()

# 1 (white/light) → Missing

# 0 (dark) → Not missing

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset has two tables:
# titles.csv (information about movies/shows) and credits.csv (actors and crew).
#
# Both tables share a common column id, which is used to merge them.
#
# The data includes details like:
# title, type, release year, genres, runtime, IMDb score, popularity, cast, crew.
#
# There are missing values in columns like:
# age_certification, seasons, imdb_score, tmdb_score, character.
#
# The merged dataset has duplicate rows because each title appears once per cast/crew member.
#
# The dataset allows analysis of genres, ratings, trends, and cast/crew insights.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
data.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'person_id', 'name', 'character', 'role'],
#       dtype='object')

# %%
# Dataset Describe
data.describe()
# Out:
#         release_year        runtime      seasons     imdb_score    imdb_votes  \
# count  124347.000000  124347.000000  8153.000000  118296.000000  1.182720e+05
# mean     1996.233234      95.536973     2.337790       5.967783  2.324281e+04
# std        27.807050      30.166352     3.130184       1.241557  8.840151e+04
# min      1912.000000       1.000000     1.000000       1.100000  5.000000e+00
# 25%      1983.000000      83.000000     1.000000       5.200000  2.870000e+02
# 50%      2009.000000      93.000000     1.000000       6.100000  1.250000e+03
# 75%      2017.000000     109.000000     2.000000       6.800000  7.067000e+03
# max      2022.000000     540.000000    49.000000       9.900000  1.133692e+06
#
#        tmdb_popularity     tmdb_score     person_id
# count    124332.000000  114082.000000  1.243470e+05
# mean         10.165321       5.992100  4.062528e+05
# std          40.739203       1.321033  5.614483e+05
# min           0.000011       0.800000  1.000000e+00
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# id – Unique identifier for each title,
# title – Name of the movie or show,
# type – Content type (MOVIE / SHOW),
# description – Summary of the title,
# release_year – Year the content was released,
# age_certification – Age rating (e.g., PG-13, TV-MA),
# runtime – Duration in minutes,
# genres – List of genres (action, drama, etc.),
# production_countries – Countries where content was produced,
# seasons – Number of seasons (for shows),
# imdb_id – IMDb unique identifier,
# imdb_score – IMDb rating,
# imdb_votes – Number of IMDb votes,
# tmdb_popularity – Popularity score from TMDB,
# tmdb_score – Rating from TMDB,
# person_id – Unique ID for actor/crew member,
# name – Name of actor/crew,
# character – Character played,
# role – Role type (ACTOR / DIRECTOR / etc.)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for col in data.columns:
    print(f"\nUnique values in '{col}':")
    print(data[col].unique())
# Out:
# Unique values in 'id':
# ['ts20945' 'tm19248' 'tm82253' ... 'tm1079144' 'tm847725' 'tm1054116']
#
# Unique values in 'title':
# ['The Three Stooges' 'The General' 'The Best Years of Our Lives' ...
#  'Jay Nog: Something from Nothing' 'Chasing' 'Baikunth']
#
# Unique values in 'type':
# ['SHOW' 'MOVIE']
#
# Unique values in 'description':
# ["The Three Stooges were an American vaudeville and comedy team active from 1922 until 1970, best known for their 190 short subject films by Columbia Pictures that have been regularly airing on television since 1958. Their hallmark was physical farce and slapstick. In films, the stooges were commonly known by their actual first names. There were a total of six stooges over the act's run (with only three active at any given time), but Moe Howard and Larry Fine were the mainstays throughout the ensemble's nearly fifty-year run."
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Remove duplicate rows
data = data.drop_duplicates()

# %%
# Convert date-related columns to numeric
data["release_year"] = pd.to_numeric(data["release_year"], errors="coerce")

# %%
# Convert numeric columns
num_cols = ["runtime", "seasons", "imdb_score", "imdb_votes",
            "tmdb_popularity", "tmdb_score"]

# %%
for col in num_cols:
    data[col] = pd.to_numeric(data[col], errors="coerce")

# %%
for col in data.columns:
    if data[col].dtype != "object":
        data[col] = data[col].fillna(data[col].median())
    else:
        data[col] = data[col].fillna(data[col].mode()[0])

# %%
#  CHECK UNIQUE VALUES
print("Unique values for each column:")
print(data.nunique())
# Out:
# Unique values for each column:
# id                       8861
# title                    8748
# type                        2
# description              8833
# release_year              110
# age_certification          11
# runtime                   204
# genres                   1965
# production_countries      482
# seasons                    30
# imdb_id                  8267
# imdb_score                 85
# imdb_votes               3623
# tmdb_popularity          5267
# tmdb_score                 88
# person_id               80508
# name                    79758
# character               71097
# role                        2
# dtype: int64

# %%
#  READY FOR ANALYSIS

print("\nDataset is cleaned, merged, and ready for EDA!")
print(data.head())
# Out:
# Dataset is cleaned, merged, and ready for EDA!
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3                 R       78
# 4                 R       78
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# merged, cleaned, and prepared the dataset for analysis by fixing missing values, converting data types, and removing duplicates. Your insights reveal that Amazon Prime’s library is modern-heavy, dominated by movies, with moderate average ratings, wide popularity differences, and mostly short-run TV shows.

# %%
data.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# person_id               0
# name                    0
# character               0
# role                    0
# dtype: int64

# %%
data.head()
# Out:
#         id              title   type  \
# 0  ts20945  The Three Stooges   SHOW
# 1  ts20945  The Three Stooges   SHOW
# 2  ts20945  The Three Stooges   SHOW
# 3  tm19248        The General  MOVIE
# 4  tm19248        The General  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  The Three Stooges were an American vaudeville ...          1934
# 2  The Three Stooges were an American vaudeville ...          1934
# 3  During America’s Civil War, Union spies steal ...          1926
# 4  During America’s Civil War, Union spies steal ...          1926
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1             TV-PG       19
# 2             TV-PG       19
# 3                 R       78
# 4                 R       78
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ***UNIVARIAT ANALYSIS***

# %%
data
# Out:
#                id              title   type  \
# 0         ts20945  The Three Stooges   SHOW
# 1         ts20945  The Three Stooges   SHOW
# 2         ts20945  The Three Stooges   SHOW
# 3         tm19248        The General  MOVIE
# 4         tm19248        The General  MOVIE
# ...           ...                ...    ...
# 124342  tm1054116           Baikunth  MOVIE
# 124343  tm1054116           Baikunth  MOVIE
# 124344  tm1054116           Baikunth  MOVIE
# 124345  tm1054116           Baikunth  MOVIE
# 124346  tm1054116           Baikunth  MOVIE
#
#                                               description  release_year  \
# 0       The Three Stooges were an American vaudeville ...          1934
# 1       The Three Stooges were an American vaudeville ...          1934
# 2       The Three Stooges were an American vaudeville ...          1934
# 3       During America’s Civil War, Union spies steal ...          1926
# ...

# %% [markdown]
# *****BOX PLOT*****

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# Box plot of inbd scure

# %%
# Chart - 1 visualization code
plt.figure(figsize=(8,6))
sns.boxplot(data=data, y='imdb_score')
plt.title('Box plot of IMDb Score', color="brown")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose the box plot because it clearly shows the distribution of IMDb scores.
# It helps identify the median, spread, and outliers in a single visual.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how IMDb scores vary across the dataset, highlighting the typical rating range. It also reveals if there are any extreme low or high outliers in the movie ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights can create a positive business impact because understanding IMDb score patterns helps platforms invest more in high-rated genres and improve content recommendations, increasing user engagement.
# There are no insights indicating negative growth, unless consistently low-rated content dominates, which would signal the need for better quality control or content curation.

# %% [markdown]
# #### Box plot of Runtime

# %%
# Chart - 2 visualization code
plt.figure(figsize=(8,6))
sns.boxplot(data=data, y='runtime')
plt.title('Box plot of Runtime', color="brown")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a boxplot because it clearly shows the distribution, median, and outliers in runtime, which helps understand variability in content length.
# It is the most efficient chart to compare spread and identify unusual runtimes quickly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The boxplot shows that most movies and shows have a runtime clustered around the median, with a moderate spread.
# There are several outliers with extremely long runtimes, indicating a few unusually lengthy titles.
# This suggests runtime varies widely, but most content follows a standard duration range.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Understanding runtime patterns helps platforms optimize content recommendations, improve user engagement, and decide the ideal runtime for new productions based on what viewers typically prefer.
# The presence of very long-runtime outliers may indicate content that viewers are less likely to finish, which can reduce watch-time and satisfaction. Producing too many unusually long titles may therefore lead to lower engagement and higher churn.

# %% [markdown]
# ####  Histogram Chart - 3

# %%
# Chart - 3 visualization code
plt.figure(figsize=(8,6))
sns.histplot(data=data, x='release_year', bins=20, kde=True)
plt.title('Histogram of Release Year', color='blue')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a histogram because it effectively shows how many titles were released in each year, helping identify trends and peak production periods.
# It is the most suitable chart for visualizing the frequency distribution of release years over time.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that the number of releases has increased significantly in recent years, indicating rapid growth in Amazon Prime’s content library.
# It also highlights older years with very few releases, showing a strong shift toward modern, recent content production.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights will help create a positive business impact because understanding which years have the highest content release allows Amazon Prime to plan future content investments and focus on periods with strong audience engagement.
# No major negative-growth insights were found, except that older years show very few releases, which may indicate gaps in classic content that Amazon could choose to improve by acquiring or remastering older titles.

# %% [markdown]
# ####  Histogram Runtime Chart - 4

# %%
# Chart - 4 visualization code
plt.figure(figsize=(8,6))
sns.histplot(data=data, x='runtime', bins=20, kde=True,color='grey')
plt.title('Histogram of Runtime', color='blue')
plt.xlabel('Runtime')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a histogram because it clearly shows how runtimes are distributed, helping identify the most common duration range for movies and shows.
# This chart is ideal for understanding frequency patterns and detecting whether runtimes are skewed toward short, medium, or long formats

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most movies or shows have runtimes around 90–120 minutes, indicating standard feature-length content is most common. A few titles have much shorter or longer runtimes, highlighting the presence of outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights can positively impact business by guiding content planning and recommendations, as most titles fall within 90–120 minutes, aligning with typical viewer preferences. However, the presence of very short or very long titles could reduce engagement for some viewers, potentially affecting watch time and subscriptions.

# %% [markdown]
# ####  Histogram of season Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(8,6))
sns.histplot(data=data, x='seasons', bins=20, kde=True,color='red')
plt.title('Histogram of Seasons', color='blue')
plt.xlabel('Seasons')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a histogram because it is ideal for showing the distribution of a single numerical variable, in this case, the number of seasons. It helps quickly identify common values, patterns, and outliers, allowing us to see how many shows have few or many seasons at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that most shows have 1–3 seasons, indicating that short series dominate the platform. A smaller number of shows have many seasons, highlighting a few long-running series as outliers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, knowing that most shows have 1–3 seasons helps the platform focus on producing or acquiring short series, which are quicker to release and easier to binge, improving viewer engagement and retention.
# Potential Negative Impact:
# A few long-running shows could dominate viewer attention, potentially limiting exposure to newer content. If viewers only focus on these long series, it may reduce the discovery of other shows, slightly affecting overall platform engagement.

# %% [markdown]
# ####  Histogram of imbd score Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize = (8,6))

sns.histplot(data = data, x = 'imdb_score', bins= 30, color = "green", kde = True)
plt.title('Histogram of imdb_score\n', color ='red')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a histogram because it is ideal for showing the distribution of a single numerical variable, in this case, IMDb scores. It helps identify how scores are spread, the most common score ranges, and any outliers in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The histogram shows that most titles have IMDb scores between 6 and 8, indicating that the majority of content is moderately to highly rated. Very few titles have extremely low or perfect scores, highlighting the presence of outliers at both ends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, the insights help the platform focus on promoting moderately to highly rated content (scores 6–8), which is more likely to engage viewers and improve satisfaction, boosting retention and subscriptions.
#
# Potential Negative Impact:
# The presence of a few low-rated titles may harm viewer perception if they are prominently displayed. Additionally, very few extremely high-rated titles suggest limited “must-watch” content, which could reduce buzz or virality compared to competitors.

# %% [markdown]
# ####  BAR plotChart - 7

# %%
a=data.type.value_counts()
a
# Out:
# type
# MOVIE    116026
# SHOW       8153
# Name: count, dtype: int64

# %%
# Chart - 7 visualization code
plt.figure(figsize=(8,6))
sns.barplot(x=a.index, y=a.values, width=0.5, color='cyan', edgecolor='black')
plt.title('Bar Plot of Type (Movie or TV Show)', color='brown')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar plot because it is ideal for comparing categorical data, in this case, the number of titles by type (Movie or TV Show). It clearly shows the count of each category and makes it easy to visually compare which type is more common on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot shows that Movies are more numerous than TV Shows on the platform, indicating that the content library is heavily focused on films. This suggests that viewers may have more options for standalone movies than for serialized content.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, knowing that Movies dominate the platform can help in content strategy and marketing, such as promoting new films or curating movie-focused recommendations, which can boost viewer engagement and subscriptions.
# The lower number of TV Shows may limit options for viewers who prefer binge-worthy or serialized content, potentially reducing engagement among this audience segment and affecting overall watch time.

# %% [markdown]
# ####  Bar plot Chart - 8

# %%
b = data.age_certification.value_counts()
b
# Out:
# age_certification
# R        93403
# PG-13    12492
# PG        9617
# G         3839
# TV-MA     1732
# TV-14     1583
# TV-PG      501
# TV-Y7      356
# TV-Y       298
# TV-G       242
# NC-17      116
# Name: count, dtype: int64

# %%
# Chart - 8 visualization code
plt.figure(figsize=(8,6))
sns.barplot(x=b.index, y=b.values, color='yellow', edgecolor='black')
plt.title('Bar Plot of Age Certification', color='brown')
plt.xlabel('Age Certification')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a bar plot because it is ideal for visualizing categorical data, in this case, age certifications. It clearly shows the count of titles in each age category, making it easy to compare which certifications are most common on the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot shows that most titles are rated “TV-MA” or “PG-13”, indicating that the platform primarily offers content suitable for mature and teenage audiences. Fewer titles fall into very restrictive or very general age categories, suggesting limited content for young children.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, knowing that most content targets teen and adult audiences can help the platform focus marketing, recommendations, and new acquisitions for this primary viewer segment, enhancing engagement and subscriptions.
#
# Potential Negative Impact:
# The limited number of titles for young children could reduce family viewership and subscription growth from households seeking child-friendly content, potentially restricting audience diversification.

# %% [markdown]
# #### Bar plot of genres Chart - 9

# %%
genre_counts =data['genres'].value_counts() 
a= genre_counts[genre_counts>1500]
a
# Out:
# genres
# ['drama']                         9853
# ['comedy']                        5582
# ['drama', 'romance']              2512
# ['horror']                        2448
# ['documentation']                 2373
# ['drama', 'comedy']               1991
# ['comedy', 'drama']               1986
# ['thriller']                      1848
# ['romance', 'comedy']             1622
# ['comedy', 'romance']             1608
# ['thriller', 'drama']             1543
# ['thriller', 'crime', 'drama']    1519
# Name: count, dtype: int64

# %%
# Chart - 9 visualization code
plt.figure(figsize=(8,6))
sns.barplot(x=a.values, y=a.index, color='orange', edgecolor='black', orient='h')
plt.title('Bar Plot of Genres', color='brown')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a horizontal bar plot because it is ideal for comparing categorical data with long category names, in this case, genres. The horizontal orientation makes it easier to read and compare genre counts without overlapping labels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot shows that Drama, Comedy, and Thriller are the most common genres on the platform, indicating a strong focus on these types of content. Less frequent genres, such as Documentary or Horror, suggest limited variety in niche categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, knowing that Drama, Comedy, and Thriller dominate can help the platform focus on producing, acquiring, and promoting content in these popular genres to maximize viewer engagement and retention.
#
# Potential Negative Impact:
# The limited number of titles in niche genres may reduce appeal for viewers seeking variety, potentially causing some audience segments to look elsewhere, which could slightly hinder growth in those areas.

# %% [markdown]
# ####  Bar Plot Of production countries Chart - 10

# %%
prod_countries = data['production_countries'].value_counts()
countries = prod_countries [prod_countries >1000]

countries
# Out:
# production_countries
# ['US']          69217
# ['IN']          11176
# ['GB']           7204
# ['CA']           3200
# []               2298
# ['JP']           2114
# ['AU']           1591
# ['FR']           1490
# ['CN']           1238
# ['GB', 'US']     1229
# ['CA', 'US']     1175
# Name: count, dtype: int64

# %%
# Chart - 10 visualization code
plt.figure(figsize=(8,6))
sns.barplot(x=countries.values, y=countries.index, orient='h', color= 'lightblue', edgecolor = 'black')
plt.title('Bar plot of production countries\n', color = 'brown')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a horizontal bar plot because it is ideal for comparing categorical data with potentially long labels, in this case, production countries. The horizontal orientation makes it easier to read country names and compare the number of productions across countries.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot shows that most titles are produced in the United States, indicating it is the dominant production country on the platform. Other countries have significantly fewer titles, highlighting a strong concentration of content from a single region.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, knowing that the United States dominates production can help the platform focus on marketing, licensing, and promoting content that aligns with viewer preferences for U.S.-produced shows, enhancing engagement and subscriptions.
#
# Potential Negative Impact:
# The limited number of titles from other countries may reduce the platform’s global appeal and content diversity, potentially limiting growth in international markets where viewers prefer local or regional content.

# %% [markdown]
# ####  Bar plot of average rating for each  age certifiaction Chart - 11

# %%
certification = data.groupby('age_certification') ['imdb_score'].mean().sort_values(ascending = False)

certification
# Out:
# age_certification
# TV-PG    7.467066
# TV-MA    7.364723
# TV-14    7.255907
# TV-Y7    6.776966
# TV-G     6.614876
# TV-Y     6.439933
# PG-13    6.109310
# PG       6.104648
# G        6.045819
# R        5.879600
# NC-17    5.294828
# Name: imdb_score, dtype: float64

# %%
# Chart - 11 visualization code
plt.figure(figsize = (8,6))
sns.barplot(x = certification.values, y = certification.index, edgecolor='black', color='cyan' )
plt.title('Bar plot of average rating for each age certification\n', color = 'brown')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a horizontal bar plot because it is ideal for comparing numerical values across categorical groups, in this case, the average IMDb score for each age certification. The horizontal orientation makes it easier to read age categories and quickly see which certifications have higher or lower average ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The bar plot shows that titles rated “TV-MA” and “PG-13” tend to have the highest average IMDb scores, indicating that content targeting teens and adults is generally better rated. Titles for very young audiences, such as “TV-Y” or “G”, have lower average ratings, suggesting that children’s content may be less popular or lower rated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, knowing that teen and adult-rated content (“TV-MA” and “PG-13”) receives higher average ratings can help the platform focus on producing, acquiring, and promoting high-quality content for these age groups, boosting viewer engagement and satisfaction.
#
# Potential Negative Impact:
# The lower average ratings for children’s content may limit family viewership and reduce appeal for households seeking high-quality kid-friendly shows, potentially restricting growth in that segment.

# %% [markdown]
# ####  Scatter plot Chart - 12

# %%
# Chart - 12 visualization code
sns.scatterplot(data=data, x='imdb_votes', y='imdb_score', color='blue')
plt.title('Scatter Plot of IMDb Votes vs IMDb Scores', color='brown')
plt.xlabel('IMDb Votes')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a scatter plot because it is ideal for visualizing the relationship between two numerical variables, in this case, IMDb votes and IMDb scores. It helps identify correlation patterns, trends, and potential outliers in the data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The scatter plot shows that titles with higher IMDb votes generally tend to have moderate to high IMDb scores, indicating a positive correlation between popularity and rating. However, there are a few titles with very high votes but lower scores, highlighting outliers where popularity does not necessarily equal high ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, understanding that more popular titles generally receive higher ratings can help the platform focus on promoting and acquiring content likely to attract both high engagement and positive reception, boosting subscriptions and viewer satisfaction.
#
# Potential Negative Impact:
# The presence of outliers with high votes but low scores suggests that some widely viewed content may disappoint viewers, which could hurt user satisfaction and retention if not carefully managed.

# %% [markdown]
# ####  Line plot Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(8,6))
sns.lineplot(data=data, x='release_year', y='runtime')
plt.title('Line Plot of Runtime vs Release Year', color='brown')
plt.xlabel('Release Year')
plt.ylabel('Runtime (minutes)')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a line plot because it is ideal for showing trends over time, in this case, how the runtime of titles changes with their release year. It helps identify patterns, increases, or decreases in runtime across different years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The line plot shows that the average runtime of titles has remained relatively stable over the years, with occasional slight increases or decreases. There are no dramatic shifts, indicating that most content continues to follow standard runtime patterns over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
# Yes, knowing that runtime trends have remained stable allows the platform to continue producing or acquiring content of standard lengths, aligning with viewer expectations and maintaining engagement.
#
# Potential Negative Impact:
# Since there are no significant increases in runtime, the platform may miss opportunities to experiment with longer or more varied content, which could limit appeal to audiences seeking unique or extended viewing experiences.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
numerical_data = data.select_dtypes(include=['int64', 'float64'])

# Compute correlation matrix
corr = numerical_data.corr()

# Plot heatmap
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap', color='brown')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a correlation heatmap because it is ideal for visualizing the strength and direction of relationships between numerical variables in a dataset. It helps quickly identify which features are positively or negatively correlated, guiding analysis and decision-making.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The correlation heatmap shows that IMDb votes and IMDb scores have a moderate positive correlation, indicating that more popular titles tend to have higher ratings. Other features, such as runtime and release year, show little to no correlation, suggesting that a title’s length does not strongly depend on its release year or rating.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(data)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I picked a pair plot because it is ideal for visualizing relationships between multiple numerical variables at once. It helps identify correlations, trends, and potential outliers across the dataset, while also showing the distribution of each variable along the diagonal.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows that IMDb votes and IMDb scores have a slight positive relationship, suggesting that more popular titles tend to receive higher ratings. Other numerical features, such as runtime and release year, show little to no clear correlation, indicating that a title’s length or release year does not strongly influence its rating or popularity.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1.Content Strategy:
#
# Focus on producing and acquiring feature-length movies (90–120 minutes) and short series (1–3 seasons), which align with viewer preferences.
#
# Expand children’s content and niche genres to attract a more diverse audience.
#
# 2,Genre & Regional Diversification:
#
# Continue investing in popular genres like Drama, Comedy, and Thriller.
#
# Acquire or co-produce content from other countries to increase global appeal and subscriber base.
#
# 3.Quality & Engagement:
#
# Promote titles with high IMDb scores and high votes to maximize engagement and satisfaction.
#
# Monitor outliers (popular but low-rated content) to avoid negative viewer experiences.
#
# 4.Data-Driven Marketing & Recommendations:
#
# Use insights from runtime, rating, genre, and age certification to personalize recommendations.
#
# Target campaigns based on viewer segments (teen/adult vs children) to improve retention and subscriptions.
#
# 5.Continuous Monitoring:
#
# Regularly analyze trends over time in runtime, ratings, and content popularity to adapt strategy proactively.
#
# 6.Outcome: By following these suggestions, the platform can increase viewer engagement, satisfaction, and subscriptions, while expanding content diversity and global reach, achieving the business objective effectively.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The analysis of platform content shows that feature-length movies and short series dominate, with most titles targeting teen and adult audiences. Popular genres like Drama, Comedy, and Thriller and a strong focus on U.S.-produced content drive engagement, while gaps exist in children’s content, niche genres, and international productions. By leveraging these insights, the platform can optimize content strategy, diversify offerings, and personalize recommendations, ultimately boosting viewer satisfaction, engagement, and subscription growth.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
